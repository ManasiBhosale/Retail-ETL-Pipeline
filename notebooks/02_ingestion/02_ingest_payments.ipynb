# %%
df_payments = spark.read.csv(
    "/Volumes/workspace/retail_schema/raw/Payments.csv",
    header=True,
    inferSchema=True
)

# %%
df_payments.show(5)
# Out:
# +------------+------------------+------------+--------------------+-------------+
# |    order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +------------+------------------+------------+--------------------+-------------+
# |Axfy13Hk4PIk|                 1| credit_card|                   1|       259.14|
# |v6px92oS8cLG|                 1| credit_card|                   8|       382.39|
# |Ulpf9skrhjfm|                 1| credit_card|                   4|       249.25|
# |bwJVWupf2keN|                 1| credit_card|                   2|        27.79|
# |Dd0QnrMk9Cj5|                 1| credit_card|                   1|        76.15|
# +------------+------------------+------------+--------------------+-------------+
# only showing top 5 rows

# %%
df_payments.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)

# %%
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, IntegerType, DecimalType, DoubleType, FloatType

payments_schema = StructType([
    StructField("order_id", StringType(), nullable=False),
    StructField("payment_sequential", IntegerType(), nullable=False),
    StructField("payment_type", StringType(), nullable=False),
    StructField("payment_installments", IntegerType(), nullable=False),
    StructField("payment_value", DoubleType(), nullable=False),
])

# %%
df_payments = (
    spark.read
    .option("header", "true")
    .schema(payments_schema)
    .csv("/Volumes/workspace/retail_schema/raw/Payments.csv")
)

# %%
df_payments.show(5)
# Out:
# +------------+------------------+------------+--------------------+-------------+
# |    order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +------------+------------------+------------+--------------------+-------------+
# |Axfy13Hk4PIk|                 1| credit_card|                   1|       259.14|
# |v6px92oS8cLG|                 1| credit_card|                   8|       382.39|
# |Ulpf9skrhjfm|                 1| credit_card|                   4|       249.25|
# |bwJVWupf2keN|                 1| credit_card|                   2|        27.79|
# |Dd0QnrMk9Cj5|                 1| credit_card|                   1|        76.15|
# +------------+------------------+------------+--------------------+-------------+
# only showing top 5 rows

# %%
df_payments.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)

# %%
from pyspark.sql.functions import col

df_payments = df_payments.filter(
    col("order_id").isNotNull()
)

# %%
df_payments.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/Volumes/workspace/retail_schema/staging/Payments")
