# %% [markdown]
# # CUSTOMER DATA EXPLORATION

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_customers = pd.read_csv('/Volumes/workspace/retail_schema/raw/Customers.csv')
df_customers.head()
# Out:
#     customer_id  customer_zip_code_prefix       customer_city customer_state
# 0  hCT0x9JiGXBQ                     58125     varzea paulista             SP
# 1  PxA7fv9spyhx                      3112  armacao dos buzios             RJ
# 2  g3nXeJkGI0Qw                      4119             jandira             SP
# 3  EOEsCQ6QlpIg                     18212          uberlandia             MG
# 4  mVz5LO2Vd6cL                     88868            ilhabela             SP

# %%
df_customers.shape
# Out:
# (127595, 4)

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127595 entries, 0 to 127594
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   customer_id               127595 non-null  object
#  1   customer_zip_code_prefix  127595 non-null  int64
#  2   customer_city             127595 non-null  object
#  3   customer_state            127595 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 3.9+ MB

# %%
df_customers.describe().T
# Out:
#                              count         mean  ...      75%      max
# customer_zip_code_prefix  127595.0  40483.68161  ...  69906.0  99990.0
#
# [1 rows x 8 columns]

# %%
df_customers.isnull().sum()
# Out:
# customer_id                 0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
df_customers.nunique()
# Out:
# customer_id                 127595
# customer_zip_code_prefix     14976
# customer_city                 4110
# customer_state                  27
# dtype: int64

# %%
city_state_counts = df_customers.groupby('customer_state')['customer_city'].nunique()

plt.figure(figsize=(10, 6))
plt.bar(city_state_counts.index, city_state_counts.values)
plt.xticks(rotation=90)
plt.title('Unique Cities per State')
plt.xlabel('State')
plt.ylabel('Number of Unique Cities')
plt.show()

# %%
customer_state_counts = df_customers.groupby('customer_state')['customer_id'].nunique()

plt.figure(figsize=(10, 6))
plt.bar(customer_state_counts.index, customer_state_counts.values)
plt.xticks(rotation=90)
plt.title('Unique Customers per State')
plt.xlabel('State')
plt.ylabel('Number of Unique Customers')
plt.show()

# %%
# zip_per_city_state = (
#     df_customers
#     .groupby(['customer_state'])['customer_zip_code_prefix']
#     .apply(lambda x: sorted(set(x)))
#     .reset_index()
# )


# zip_per_city_state
